# %%
# for manipulations
import numpy as np
import pandas as pd

# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# for interactivity
from ipywidgets import interact

# %%
# read the dataset
data = pd.read_csv(r'E:\FOM PPT\Sem-3\AP-2\AP-2 Survey Questionnaires.csv')

# %%
# check the shape of the dataset
print("shape of the dataset : ", data.shape)
# Out:
# shape of the dataset :  (55, 24)

# %%
# check the head of the dataset
data.head(10)
# Out:
#                       Timestamp Tools Name                       Factors  \
# 0  2022/03/12 11:12:20 AM GMT+1  Helium 10         All round performance
# 1  2022/03/13 12:00:28 AM GMT+1      Keepa               Quality service
# 2   2022/03/13 1:14:27 PM GMT+1   Amalytix  Functionalities and Features
# 3   2022/03/13 1:15:02 PM GMT+1      Keepa               Affordable cost
# 4   2022/03/13 1:15:33 PM GMT+1   Amalytix  Functionalities and Features
# 5   2022/03/13 7:50:29 PM GMT+1      Keepa  Functionalities and Features
# 6   2022/03/13 8:01:13 PM GMT+1      Keepa                   Easy to use
# 7   2022/03/13 8:03:40 PM GMT+1   Amalytix               Affordable cost
# 8   2022/03/14 1:10:16 AM GMT+1  Helium 10         All round performance
# 9   2022/03/14 1:13:47 AM GMT+1    Alimama               Affordable cost
#
#         Year         Days  Cross channel marketing Marketplace Routes  \
# 0  2-4 years     One week                        1            B2 B2 C
# ...

# %%
# check if there is any missing value present in the dataset
data.isnull().sum()
# Out:
# Timestamp                   0
# Tools Name                  0
# Factors                     0
# Year                        0
# Days                        0
# Cross channel marketing     0
# Marketplace Routes          0
# Business growth             0
# Digital and Advanced        0
# Key factor                  0
# Customer Data Security      0
# Payment methods             0
# Recommendation system       0
# The sellers complexity      0
# Quality Service             0
# Software tool experience    0
# Cross_channel_marketing     0
# Business_growth             0
# Digital_Advanced            0
# Customer_Data_Security      0
# Recommendation_system       0
# The_sellers_complexity      0
# Quality_Service             0
# Software_tool_experience    0
# dtype: int64

# %%
data.describe()
# Out:
#        Cross channel marketing  Business growth   Digital and Advanced  \
# count                55.000000         55.000000             55.000000
# mean                  2.054545          2.090909              2.181818
# std                   1.366507          1.309124              1.362064
# min                   1.000000          1.000000              1.000000
# 25%                   1.000000          1.000000              1.000000
# 50%                   1.000000          2.000000              2.000000
# 75%                   3.000000          3.000000              3.000000
# max                   5.000000          5.000000              5.000000
#
#        Customer Data Security   Payment methods   Recommendation system  \
# count                55.000000         55.000000              55.000000
# mean                  2.181818          2.290909               2.254545
# std                   1.388990          1.356367               1.250454
# ...

# %%
#Get information

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Timestamp                 55 non-null     object
#  1   Tools Name                55 non-null     object
#  2   Factors                   55 non-null     object
#  3   Year                      55 non-null     object
#  4   Days                      55 non-null     object
#  5   Cross channel marketing   55 non-null     int64
#  6   Marketplace Routes        55 non-null     object
#  7   Business growth           55 non-null     int64
#  8   Digital and Advanced      55 non-null     int64
#  9   Key factor                55 non-null     object
#  10  Customer Data Security    55 non-null     int64
#  11  Payment methods           55 non-null     int64
#  12  Recommendation system     55 non-null     int64
#  13  The sellers complexity    55 non-null     int64
# ...

# %%
from matplotlib.pyplot import figure
sns.pairplot(data,x_vars=['Software tool experience'],y_vars=['Factors'],hue='Tools Name',size=7 )
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# get the correlation
data.corr()
# Out:
#                           Cross channel marketing  Business growth   \
# Cross channel marketing                  1.000000          0.659689
# Business growth                          0.659689          1.000000
# Digital and Advanced                     0.601487          0.748701
# Customer Data Security                   0.531287          0.744372
# Payment methods                          0.550787          0.662724
# Recommendation system                    0.631133          0.686976
# The sellers complexity                   0.666297          0.733804
# Quality Service                          0.603713          0.755347
# Software tool experience                -0.041266         -0.183016
#
#                           Digital and Advanced  Customer Data Security   \
# Cross channel marketing               0.601487                 0.531287
# Business growth                       0.748701                 0.744372
# ...

# %%
# visualize the correlation
plt.figure(figsize=(7,7))
sns.heatmap(data.corr(), annot=True, fmt= '.0%')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Quality_Service',y ='The sellers complexity ', data=data)
# Out:
# <AxesSubplot:xlabel='Quality_Service', ylabel='The sellers complexity '>

# %%
sns.boxplot(x='Recommendation_system',y ='The sellers complexity ', data=data)
# Out:
# <AxesSubplot:xlabel='Recommendation_system', ylabel='The sellers complexity '>

# %%
sns.boxplot(x='Quality Service',y ='Customer_Data_Security ', data=data)
# Out:
# <AxesSubplot:xlabel='Quality Service', ylabel='Customer_Data_Security '>

# %%
sns.boxplot(x='Tools Name',y ='Software tool experience', data=data)
# Out:
# <AxesSubplot:xlabel='Tools Name', ylabel='Software tool experience'>
